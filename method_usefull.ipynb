# %%
# Display full record
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df[df['total_points'] == 100][cols])
    print(len(df[df['total_points'] == 100][cols]))
